# %% [markdown]
# # Parkinson's Disease Detection using Parkinson's Spiral Drawing and CNN
#
# ![](https://cainvas-static.s3.amazonaws.com/media/user_data/Yuvnish17/Parkinsons-Disease.png)

# %% [markdown]
# ### Cloning GitHub Repository for dataset

# %%
! git clone https://github.com/Yuvnish017/Parkinsons_Disease_Detection_using_Parkinsons_Spiral_Drawing.git
# Out:
# Cloning into 'Parkinsons_Disease_Detection_using_Parkinsons_Spiral_Drawing'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 8 (delta 0), reused 8 (delta 0), pack-reused 0
# Unpacking objects: 100% (8/8), done.

# %% [markdown]
# ### Importing the required Libraries and packages

# %%
import numpy as np
import cv2
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dropout, Flatten, Dense, MaxPool2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam, SGD
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import pandas as pd

# %% [markdown]
# ### Loading Dataset

# %%
data_train = np.load('/content/Parkinsons_Disease_Detection_using_Parkinsons_Spiral_Drawing/dataset/train_set.npz', allow_pickle=True)
x_train = data_train['arr_0']
y_train = data_train['arr_1']

print(x_train.shape)
print(y_train.shape)
# Out:
# (72, 256, 256, 3)
# (72,)

# %%
data_test = np.load('/content/Parkinsons_Disease_Detection_using_Parkinsons_Spiral_Drawing/dataset/test_set.npz', allow_pickle=True)
x_test = data_test['arr_0']
y_test = data_test['arr_1']

print(x_test.shape)
print(y_test.shape)
# Out:
# (30, 256, 256, 3)
# (30,)

# %% [markdown]
# ### Data Distribution

# %%
unique_train, count = np.unique(y_train, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(unique_train, count).set_title("Number of training images per category:")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
unique_test, count_test = np.unique(y_test, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(unique_test, count_test).set_title("Number of testing images per category:")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# As can be seen, though the dataset is balanced but contains very less data points

# %% [markdown]
# ### Augmenting the Dataset

# %%
train_data_generator = ImageDataGenerator(rotation_range=360, 
                                    width_shift_range=0.0, 
                                    height_shift_range=0.0, 
                                    horizontal_flip=True, 
                                    vertical_flip=True)

x = list(x_train)
y = list(y_train)

x_aug_train = []
y_aug_train = []

for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = train_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(70):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_train.append(aug_image)
        y_aug_train.append(v)
print(len(x_aug_train))
print(len(y_aug_train))

x_train = x + x_aug_train
y_train = y + y_aug_train
print(len(x_train))
print(len(y_train))

test_data_generator = ImageDataGenerator(rotation_range=360, 
                                    width_shift_range=0.0, 
                                    height_shift_range=0.0, 
                                    horizontal_flip=True, 
                                    vertical_flip=True)

x = list(x_test)
y = list(y_test)

x_aug_test = []
y_aug_test = []

for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = test_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(20):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_test.append(aug_image)
        y_aug_test.append(v)
print(len(x_aug_test))
print(len(y_aug_test))

x_test = x + x_aug_test
y_test = y + y_aug_test
print(len(x_test))
print(len(y_test))
# Out:
# 5040
# 5040
# 5112
# 5112
# 600
# 600
# 630
# 630

# %% [markdown]
# ### Visualizing the Images in Train and Test Set
#
# ##### Images in Train Set

# %%
# print(y_test)
figure1 = plt.figure(figsize=(5, 5))
idx_healthy = [i for (i, v) in enumerate(y_train) if v=='healthy']
img_healthy = x_train[idx_healthy[-1]]
plt.imshow(img_healthy)
plt.title('Spiral Drawing by a Healthy Person')
plt.axis('off')
plt.show()

figure2 = plt.figure(figsize=(5, 5))
idx_parkinson = [i for (i, v) in enumerate(y_train) if v=='parkinson']
img_parkinson = x_train[idx_parkinson[-1]]
plt.imshow(img_parkinson)
plt.title("Spiral Drawing by a Person having Parkinson's Disease")
plt.axis('off')
plt.show()

# %% [markdown]
# #### Images in Test Set

# %%
figure1 = plt.figure(figsize=(5, 5))
idx_healthy = [i for (i, v) in enumerate(y_test) if v=='healthy']
img_healthy = x_test[idx_healthy[-1]]
plt.imshow(img_healthy)
plt.title('Spiral Drawing by a Healthy Person')
plt.axis('off')
plt.show()

figure2 = plt.figure(figsize=(5, 5))
idx_parkinson = [i for (i, v) in enumerate(y_test) if v=='parkinson']
img_parkinson = x_test[idx_parkinson[-1]]
plt.imshow(img_parkinson)
plt.title("Spiral Drawing by a Person having Parkinson's Disease")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Preprocessing the Images

# %%
for i in range(len(x_train)):
    img = x_train[i]
    img = cv2.resize(img, (128, 128))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    x_train[i] = img
    
for i in range(len(x_test)):
    img = x_test[i]
    img = cv2.resize(img, (128, 128))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    x_test[i] = img

x_train = np.array(x_train)
x_test = np.array(x_test)

x_train = x_train/255.0
x_test = x_test/255.0

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
print(y_train.shape)

label_encoder = LabelEncoder()
y_test = label_encoder.fit_transform(y_test)
print(y_test.shape)
# Out:
# (5112,)
# (630,)

# %% [markdown]
# ### Data Distribution after Augmentation

# %%
unique_train, count = np.unique(y_train, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(unique_train, count).set_title("Number of training images per category after augmentation:")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
unique_test, count_test = np.unique(y_test, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(unique_test, count_test).set_title("Number of test set images per category after augmentation:")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (5112, 128, 128, 1)
# (5112, 2)
# (630, 128, 128, 1)
# (630, 2)

# %% [markdown]
# ### Defining the Model

# %%
def parkinson_disease_detection_model(input_shape=(128, 128, 1)):
    regularizer = tf.keras.regularizers.l2(0.001)
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(128, (5, 5), padding='same', strides=(1, 1), name='conv1', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((9, 9), strides=(3, 3)))

    model.add(Conv2D(64, (5, 5), padding='same', strides=(1, 1), name='conv2', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((7, 7), strides=(3, 3)))
    
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv3', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((5, 5), strides=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv4', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((3, 3), strides=(2, 2)))    
    
    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu', kernel_initializer='glorot_uniform', name='fc1'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax', kernel_initializer='glorot_uniform', name='fc3'))
    
    optimizer = Adam(3.15e-5)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model= parkinson_disease_detection_model(input_shape=(128, 128, 1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 128, 128, 128)     3328
#
#  max_pooling2d (MaxPooling2D  (None, 40, 40, 128)      0
#  )
#
#  conv2 (Conv2D)              (None, 40, 40, 64)        204864
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  conv3 (Conv2D)              (None, 12, 12, 32)        18464
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 32)         0
#  2D)
#
#  conv4 (Conv2D)              (None, 4, 4, 32)          9248
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 32)                0
#
#  dropout (Dropout)           (None, 32)                0
#
#  fc1 (Dense)                 (None, 64)                2112
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  fc3 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 238,146
# Trainable params: 238,146
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the Model

# %%
hist = model.fit(x_train, y_train, batch_size=128, epochs=70, validation_data=(x_test, y_test))
# Out:
# Epoch 1/70
# 40/40 [==============================] - 31s 476ms/step - loss: 0.8529 - accuracy: 0.5045 - val_loss: 0.8476 - val_accuracy: 0.5000
# Epoch 2/70
# 40/40 [==============================] - 14s 346ms/step - loss: 0.8445 - accuracy: 0.5002 - val_loss: 0.8400 - val_accuracy: 0.5000
# Epoch 3/70
# 40/40 [==============================] - 14s 346ms/step - loss: 0.8371 - accuracy: 0.5041 - val_loss: 0.8332 - val_accuracy: 0.5000
# Epoch 4/70
# 40/40 [==============================] - 14s 347ms/step - loss: 0.8297 - accuracy: 0.5139 - val_loss: 0.8269 - val_accuracy: 0.5000
# Epoch 5/70
# 40/40 [==============================] - 14s 350ms/step - loss: 0.8239 - accuracy: 0.5078 - val_loss: 0.8208 - val_accuracy: 0.6111
# Epoch 6/70
# 40/40 [==============================] - 14s 348ms/step - loss: 0.8188 - accuracy: 0.5000 - val_loss: 0.8153 - val_accuracy: 0.5587
# Epoch 7/70
# 40/40 [==============================] - 14s 349ms/step - loss: 0.8128 - accuracy: 0.5135 - val_loss: 0.8101 - val_accuracy: 0.5000
# Epoch 8/70
# 40/40 [==============================] - 14s 349ms/step - loss: 0.8080 - accuracy: 0.5041 - val_loss: 0.8050 - val_accuracy: 0.5000
# Epoch 9/70
# 40/40 [==============================] - 14s 351ms/step - loss: 0.8026 - accuracy: 0.5254 - val_loss: 0.8008 - val_accuracy: 0.5000
# Epoch 10/70
# 40/40 [==============================] - 14s 350ms/step - loss: 0.7981 - accuracy: 0.5213 - val_loss: 0.7955 - val_accuracy: 0.5000
# Epoch 11/70
# 40/40 [==============================] - 15s 368ms/step - loss: 0.7936 - accuracy: 0.5274 - val_loss: 0.7901 - val_accuracy: 0.7238
# Epoch 12/70
# 40/40 [==============================] - 14s 351ms/step - loss: 0.7903 - accuracy: 0.5209 - val_loss: 0.7861 - val_accuracy: 0.6587
# Epoch 13/70
# 40/40 [==============================] - 14s 350ms/step - loss: 0.7859 - accuracy: 0.5272 - val_loss: 0.7822 - val_accuracy: 0.6825
# Epoch 14/70
# 40/40 [==============================] - 14s 349ms/step - loss: 0.7825 - accuracy: 0.5243 - val_loss: 0.7788 - val_accuracy: 0.5794
# Epoch 15/70
# 40/40 [==============================] - 14s 350ms/step - loss: 0.7791 - accuracy: 0.5286 - val_loss: 0.7744 - val_accuracy: 0.7317
# Epoch 16/70
# 40/40 [==============================] - 14s 351ms/step - loss: 0.7750 - accuracy: 0.5403 - val_loss: 0.7703 - val_accuracy: 0.6317
# Epoch 17/70
# 40/40 [==============================] - 14s 352ms/step - loss: 0.7718 - accuracy: 0.5452 - val_loss: 0.7665 - val_accuracy: 0.6984
# Epoch 18/70
# 40/40 [==============================] - 14s 351ms/step - loss: 0.7700 - accuracy: 0.5448 - val_loss: 0.7635 - val_accuracy: 0.6857
# Epoch 19/70
# 40/40 [==============================] - 14s 352ms/step - loss: 0.7640 - accuracy: 0.5736 - val_loss: 0.7601 - val_accuracy: 0.5937
# Epoch 20/70
# 40/40 [==============================] - 15s 368ms/step - loss: 0.7605 - accuracy: 0.5839 - val_loss: 0.7541 - val_accuracy: 0.6619
# Epoch 21/70
# 40/40 [==============================] - 14s 353ms/step - loss: 0.7562 - accuracy: 0.5839 - val_loss: 0.7488 - val_accuracy: 0.7302
# Epoch 22/70
# 40/40 [==============================] - 14s 352ms/step - loss: 0.7501 - accuracy: 0.6062 - val_loss: 0.7411 - val_accuracy: 0.8016
# Epoch 23/70
# 40/40 [==============================] - 14s 354ms/step - loss: 0.7453 - accuracy: 0.6131 - val_loss: 0.7356 - val_accuracy: 0.6619
# Epoch 24/70
# 40/40 [==============================] - 15s 370ms/step - loss: 0.7372 - accuracy: 0.6289 - val_loss: 0.7265 - val_accuracy: 0.6635
# Epoch 25/70
# 40/40 [==============================] - 14s 355ms/step - loss: 0.7267 - accuracy: 0.6356 - val_loss: 0.7226 - val_accuracy: 0.5810
# Epoch 26/70
# 40/40 [==============================] - 14s 355ms/step - loss: 0.7181 - accuracy: 0.6551 - val_loss: 0.7046 - val_accuracy: 0.7905
# Epoch 27/70
# 40/40 [==============================] - 14s 357ms/step - loss: 0.7053 - accuracy: 0.6784 - val_loss: 0.6974 - val_accuracy: 0.6698
# Epoch 28/70
# 40/40 [==============================] - 14s 357ms/step - loss: 0.6916 - accuracy: 0.6925 - val_loss: 0.6772 - val_accuracy: 0.7968
# Epoch 29/70
# 40/40 [==============================] - 14s 356ms/step - loss: 0.6771 - accuracy: 0.7126 - val_loss: 0.6657 - val_accuracy: 0.7667
# Epoch 30/70
# 40/40 [==============================] - 14s 357ms/step - loss: 0.6652 - accuracy: 0.7138 - val_loss: 0.6768 - val_accuracy: 0.6397
# Epoch 31/70
# 40/40 [==============================] - 14s 359ms/step - loss: 0.6491 - accuracy: 0.7273 - val_loss: 0.6810 - val_accuracy: 0.6460
# Epoch 32/70
# 40/40 [==============================] - 14s 359ms/step - loss: 0.6441 - accuracy: 0.7328 - val_loss: 0.6610 - val_accuracy: 0.6397
# Epoch 33/70
# 40/40 [==============================] - 14s 360ms/step - loss: 0.6249 - accuracy: 0.7473 - val_loss: 0.6188 - val_accuracy: 0.7905
# Epoch 34/70
# 40/40 [==============================] - 14s 359ms/step - loss: 0.6141 - accuracy: 0.7529 - val_loss: 0.6298 - val_accuracy: 0.6587
# Epoch 35/70
# 40/40 [==============================] - 14s 359ms/step - loss: 0.6000 - accuracy: 0.7666 - val_loss: 0.6089 - val_accuracy: 0.7127
# Epoch 36/70
# 40/40 [==============================] - 14s 360ms/step - loss: 0.5920 - accuracy: 0.7733 - val_loss: 0.6083 - val_accuracy: 0.6873
# Epoch 37/70
# 40/40 [==============================] - 14s 361ms/step - loss: 0.5873 - accuracy: 0.7745 - val_loss: 0.5870 - val_accuracy: 0.7540
# Epoch 38/70
# 40/40 [==============================] - 14s 360ms/step - loss: 0.5715 - accuracy: 0.7827 - val_loss: 0.6042 - val_accuracy: 0.6714
# Epoch 39/70
# 40/40 [==============================] - 14s 360ms/step - loss: 0.5623 - accuracy: 0.7879 - val_loss: 0.5957 - val_accuracy: 0.6937
# Epoch 40/70
# 40/40 [==============================] - 14s 360ms/step - loss: 0.5608 - accuracy: 0.7833 - val_loss: 0.5734 - val_accuracy: 0.7254
# Epoch 41/70
# 40/40 [==============================] - 14s 360ms/step - loss: 0.5559 - accuracy: 0.7883 - val_loss: 0.5921 - val_accuracy: 0.6778
# Epoch 42/70
# 40/40 [==============================] - 14s 360ms/step - loss: 0.5472 - accuracy: 0.7913 - val_loss: 0.5512 - val_accuracy: 0.7746
# Epoch 43/70
# 40/40 [==============================] - 14s 361ms/step - loss: 0.5292 - accuracy: 0.8032 - val_loss: 0.5380 - val_accuracy: 0.7825
# Epoch 44/70
# 40/40 [==============================] - 14s 359ms/step - loss: 0.5288 - accuracy: 0.8030 - val_loss: 0.5614 - val_accuracy: 0.8175
# Epoch 45/70
# 40/40 [==============================] - 14s 360ms/step - loss: 0.5185 - accuracy: 0.8159 - val_loss: 0.5459 - val_accuracy: 0.7317
# Epoch 46/70
# 40/40 [==============================] - 14s 359ms/step - loss: 0.5115 - accuracy: 0.8206 - val_loss: 0.5680 - val_accuracy: 0.6968
# Epoch 47/70
# 40/40 [==============================] - 14s 360ms/step - loss: 0.5107 - accuracy: 0.8165 - val_loss: 0.5761 - val_accuracy: 0.7000
# Epoch 48/70
# 40/40 [==============================] - 14s 359ms/step - loss: 0.4952 - accuracy: 0.8298 - val_loss: 0.5064 - val_accuracy: 0.8222
# Epoch 49/70
# 40/40 [==============================] - 14s 360ms/step - loss: 0.4901 - accuracy: 0.8316 - val_loss: 0.5039 - val_accuracy: 0.7968
# Epoch 50/70
# 40/40 [==============================] - 14s 359ms/step - loss: 0.4900 - accuracy: 0.8347 - val_loss: 0.4980 - val_accuracy: 0.8270
# Epoch 51/70
# 40/40 [==============================] - 14s 360ms/step - loss: 0.4799 - accuracy: 0.8378 - val_loss: 0.5027 - val_accuracy: 0.8333
# Epoch 52/70
# 40/40 [==============================] - 14s 359ms/step - loss: 0.4725 - accuracy: 0.8388 - val_loss: 0.4975 - val_accuracy: 0.7746
# Epoch 53/70
# 40/40 [==============================] - 14s 361ms/step - loss: 0.4622 - accuracy: 0.8496 - val_loss: 0.4824 - val_accuracy: 0.8302
# Epoch 54/70
# 40/40 [==============================] - 14s 359ms/step - loss: 0.4537 - accuracy: 0.8504 - val_loss: 0.4780 - val_accuracy: 0.8286
# Epoch 55/70
# 40/40 [==============================] - 14s 360ms/step - loss: 0.4497 - accuracy: 0.8533 - val_loss: 0.4715 - val_accuracy: 0.8302
# Epoch 56/70
# 40/40 [==============================] - 14s 359ms/step - loss: 0.4357 - accuracy: 0.8646 - val_loss: 0.4656 - val_accuracy: 0.8381
# Epoch 57/70
# 40/40 [==============================] - 14s 360ms/step - loss: 0.4479 - accuracy: 0.8552 - val_loss: 0.4944 - val_accuracy: 0.8333
# Epoch 58/70
# 40/40 [==============================] - 14s 359ms/step - loss: 0.4397 - accuracy: 0.8621 - val_loss: 0.4611 - val_accuracy: 0.8302
# Epoch 59/70
# 40/40 [==============================] - 14s 359ms/step - loss: 0.4222 - accuracy: 0.8638 - val_loss: 0.4661 - val_accuracy: 0.8413
# Epoch 60/70
# 40/40 [==============================] - 14s 359ms/step - loss: 0.4139 - accuracy: 0.8756 - val_loss: 0.4654 - val_accuracy: 0.8429
# Epoch 61/70
# 40/40 [==============================] - 14s 360ms/step - loss: 0.4080 - accuracy: 0.8768 - val_loss: 0.4601 - val_accuracy: 0.8429
# Epoch 62/70
# 40/40 [==============================] - 14s 359ms/step - loss: 0.4112 - accuracy: 0.8732 - val_loss: 0.4470 - val_accuracy: 0.8365
# Epoch 63/70
# 40/40 [==============================] - 14s 360ms/step - loss: 0.4076 - accuracy: 0.8773 - val_loss: 0.4622 - val_accuracy: 0.8444
# Epoch 64/70
# 40/40 [==============================] - 14s 359ms/step - loss: 0.3902 - accuracy: 0.8828 - val_loss: 0.4403 - val_accuracy: 0.8413
# Epoch 65/70
# 40/40 [==============================] - 14s 360ms/step - loss: 0.3930 - accuracy: 0.8844 - val_loss: 0.4415 - val_accuracy: 0.8460
# Epoch 66/70
# 40/40 [==============================] - 14s 359ms/step - loss: 0.3901 - accuracy: 0.8838 - val_loss: 0.4370 - val_accuracy: 0.8571
# Epoch 67/70
# 40/40 [==============================] - 14s 360ms/step - loss: 0.3783 - accuracy: 0.8877 - val_loss: 0.4542 - val_accuracy: 0.8444
# Epoch 68/70
# 40/40 [==============================] - 14s 359ms/step - loss: 0.3692 - accuracy: 0.8924 - val_loss: 0.4754 - val_accuracy: 0.8349
# Epoch 69/70
# 40/40 [==============================] - 14s 360ms/step - loss: 0.3664 - accuracy: 0.8951 - val_loss: 0.4373 - val_accuracy: 0.8476
# Epoch 70/70
# 40/40 [==============================] - 14s 359ms/step - loss: 0.3683 - accuracy: 0.8959 - val_loss: 0.4266 - val_accuracy: 0.8556

# %% [markdown]
# ### Loss and Accuracy Plot

# %%
figure = plt.figure(figsize=(10, 10))
plt.plot(hist.history['accuracy'], label='Train_accuracy')
plt.plot(hist.history['val_accuracy'], label='Test_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

figure2 = plt.figure(figsize=(10, 10))
plt.plot(hist.history['loss'], label='Train_loss')
plt.plot(hist.history['val_loss'], label='Test_loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ### Classification Report

# %%
ypred = model.predict(x_test)
ypred = np.argmax(ypred, axis=1)
y_test_pred = np.argmax(y_test, axis=1)
print(classification_report(y_test_pred, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       315
#            1       0.87      0.83      0.85       315
#
#     accuracy                           0.86       630
#    macro avg       0.86      0.86      0.86       630
# weighted avg       0.86      0.86      0.86       630

# %% [markdown]
# ### Confusion Matrix

# %%
matrix = confusion_matrix(y_test_pred, ypred)
df_cm = pd.DataFrame(matrix, index=[0, 1], columns=[0, 1])
figure = plt.figure(figsize=(5, 5))
sns.heatmap(df_cm, annot=True, fmt='d')

# %% [markdown]
# ### Saving the Model

# %%
model.save('parkinson_disease_detection.h5')

# %% [markdown]
# ### Testing Model on Images

# %%
labels = ['Healthy', 'Parkinson']
image_healthy = cv2.imread('/content/Parkinsons_Disease_Detection_using_Parkinsons_Spiral_Drawing/dataset/test_image_healthy.png')
image_parkinson = cv2.imread('/content/Parkinsons_Disease_Detection_using_Parkinsons_Spiral_Drawing/dataset/test_image_parkinson.png')

image_healthy = cv2.resize(image_healthy, (128, 128))
image_healthy = cv2.cvtColor(image_healthy, cv2.COLOR_BGR2GRAY)
image_healthy = np.array(image_healthy)
image_healthy = np.expand_dims(image_healthy, axis=0)
image_healthy = np.expand_dims(image_healthy, axis=-1)

image_parkinson = cv2.resize(image_parkinson, (128, 128))
image_parkinson = cv2.cvtColor(image_parkinson, cv2.COLOR_BGR2GRAY)
image_parkinson = np.array(image_parkinson)
image_parkinson = np.expand_dims(image_parkinson, axis=0)
image_parkinson = np.expand_dims(image_parkinson, axis=-1)

# %%
ypred_healthy = model.predict(image_healthy)
ypred_parkinson = model.predict(image_parkinson)

# %%
figure = plt.figure(figsize=(2, 2))
img_healthy = np.squeeze(image_healthy, axis=0)
img_healthy = np.squeeze(img_healthy, axis=-1)
plt.imshow(img_healthy)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_healthy[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
image_parkinson = np.squeeze(image_parkinson, axis=0)
image_parkinson = np.squeeze(image_parkinson, axis=-1)
plt.imshow(image_parkinson)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_parkinson[0], axis=0)]}')
plt.show()
